# %%
from __future__ import print_function, division

import pandas as pd
import requests
from bs4 import BeautifulSoup
import pprint

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os
import time

# %%
data = pd.read_csv('main_df_Aug1.csv')

# %%
test_data = data.loc[:20, :].drop('Unnamed: 0', axis=1)

# %%
test_data
# Out:
#                name                                  industry  \
# 0           Walmart         General Merchandise & Superstores
# 1            Target       Department, Clothing, & Shoe Stores
# 2   Bank of America                     Banks & Credit Unions
# 3           US Army                          Federal Agencies
# 4              AT&T               Telecommunications Services
# 5               IBM                                Consulting
# 6          Best Buy  Consumer Electronics & Appliances Stores
# 7    The Home Depot            Home Centers & Hardware Stores
# 8            Macy's       Department, Clothing, & Shoe Stores
# 9         Microsoft              Computer Hardware & Software
# 10           Lowe's            Home Centers & Hardware Stores
# 11        Starbucks     Fast-Food & Quick-Service Restaurants
# 12       McDonald's     Fast-Food & Quick-Service Restaurants
# 13  Hewlett-Packard              Computer Hardware & Software
# ...

# %%
names = list(test_data.loc[:,'name'])

# %%
chromedriver = "/Users/Saniya/Downloads/chromedriver" 
os.environ["webdriver.chrome.driver"] = chromedriver

driver = webdriver.Chrome(chromedriver)

driver.get("https://www.glassdoor.com")
driver.find_element_by_link_text('')
driver.get("https://www.glassdoor.com/Reviews/index.htm")
time.sleep(15)
search_bar = driver.find_element_by_name("sc.keyword")
reviews={}
# for name in names:
# search_bar = driver.find_element_by_name("sc.keyword")
search_bar.send_keys(names[4]) # change to send_keys(name)
search_bar.send_keys(Keys.RETURN)
links = driver.find_elements_by_link_text(names[4]) # change to send_keys(name)
links[0].click() if links else none
time.sleep(5)
driver.find_element_by_xpath('//*[@id="SiteSrchTop"]/form/div/div[1]/span/span').click()
time.sleep(5)
driver.find_element_by_xpath('//*[@id="EIHdrModule"]/div[2]/div/a[2]/span[1]').click()
review=driver.find_element_by_xpath('//*[@id="empReview_7800395"]/div/div[2]/div/div[2]/h2/a/span').text
print(review)
# if names[4] not in reviews:
#     reviews[names[4]]=
driver.close()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-47-5d955fcd4045> in <module>()
#      17 time.sleep(5)
#      18 driver.find_element_by_xpath('//*[@id="EIHdrModule"]/div[2]/div/a[2]/span[1]').click()
# ---> 19 review=driver.find_element_by_xpath('//*[@id="empReview_7800395"]/div/div[2]/div/div[2]/h2/a/span').text
#      20 print(review)
#      21 # if names[4] not in reviews:
#
# //anaconda/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     291             driver.find_element_by_xpath('//div/td[1]')
#     292         """
# --> 293         return self.find_element(by=By.XPATH, value=xpath)
#     294
#     295     def find_elements_by_xpath(self, xpath):
#
# //anaconda/lib/python3.5/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
# ...

# %%
print (names[0]) if len(names)!=0 else none
# Out:
# Walmart

# %%
d = {}
if 'hello' not in d:
    d['hello']=[]
print( d)
# Out:
# {'hello': []}
